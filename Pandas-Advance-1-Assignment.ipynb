# %% [markdown]
# # Q1. List any five functions of the pandas library with execution.

# %% [markdown]
# - Here are five common functions of the pandas library along with examples of their execution:

# %%
# read_csv(): This function is used to read a CSV file and convert it into a DataFrame.

import pandas as pd
df = pd.read_csv('services.csv')
(df)
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
# head(): This function is used to return the first n rows of a DataFrame.

df.head(10)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
# 5   6            6         NaN               NaN            NaN
# 6   7            7         NaN               NaN            NaN
# 7   8            8         NaN               NaN            NaN
# 8   9            9         NaN               NaN            NaN
# 9  10           10         NaN               NaN            NaN
#
#                                  application_process  \
# 0                         Walk in or apply by phone.
# 1                 Apply by phone for an appointment.
# 2        Phone for information (403-4300 Ext. 4322).
# ...

# %%
# describe(): This function generates descriptive statistics that summarize the central tendency, dispersion, and shape of a dataset’s distribution, excluding NaN values.
df.describe()
# Out:
#              id  location_id  program_id
# count  23.00000    23.000000         0.0
# mean   12.00000    11.956522         NaN
# std     6.78233     6.711444         NaN
# min     1.00000     1.000000         NaN
# 25%     6.50000     6.500000         NaN
# 50%    12.00000    12.000000         NaN
# 75%    17.50000    17.500000         NaN
# max    23.00000    22.000000         NaN

# %%
# groupby(): This function is used to split the data into groups based on some criteria.
grouped_df = df.groupby('location_id').mean()
grouped_df
# Out:
#                id  program_id
# location_id
# 1             1.0         NaN
# 2             2.0         NaN
# 3             3.0         NaN
# 4             4.0         NaN
# 5             5.0         NaN
# 6             6.0         NaN
# 7             7.0         NaN
# 8             8.0         NaN
# 9             9.0         NaN
# 10           10.0         NaN
# 11           11.0         NaN
# 12           12.0         NaN
# 13           13.0         NaN
# 14           14.0         NaN
# 15           15.0         NaN
# 16           16.0         NaN
# 17           17.0         NaN
# 18           18.0         NaN
# 19           19.0         NaN
# 20           20.0         NaN
# 21           21.0         NaN
# 22           22.5         NaN

# %%
# merge(): This function is used to merge DataFrame objects with a database-style join.
# Merging two DataFrames
df1 = pd.DataFrame({'key': ['A', 'B', 'C'], 'value': [1, 2, 3]})
df2 = pd.DataFrame({'key': ['B', 'C', 'D'], 'value': [4, 5, 6]})
merged_df = pd.merge(df1, df2, on='key')
merged_df
# Out:
#   key  value_x  value_y
# 0   B        2        4
# 1   C        3        5

# %% [markdown]
# # Q2. Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the DataFrame with a new index that starts from 1 and increments by 2 for each row.

# %%
import pandas as pd

def reindex_dataframe(df):
    # Create a new index starting from 1 and incrementing by 2
    new_index = range(1, 2 * len(df) + 1, 2)
    
    # Re-index the DataFrame
    df_reindexed = df.copy()
    df_reindexed.index = new_index
    
    return df_reindexed

# %%
# Example DataFrame
data = {
    'A': [10, 20, 30, 40],
    'B': [100, 200, 300, 400],
    'C': [1000, 2000, 3000, 4000]
}

df = pd.DataFrame(data)
print("Original DataFrame:")
print(df)

# Re-indexing the DataFrame
df_reindexed = reindex_dataframe(df)
print("\nRe-indexed DataFrame:")
print(df_reindexed)
# Out:
# Original DataFrame:
#     A    B     C
# 0  10  100  1000
# 1  20  200  2000
# 2  30  300  3000
# 3  40  400  4000
#
# Re-indexed DataFrame:
#     A    B     C
# 1  10  100  1000
# 3  20  200  2000
# 5  30  300  3000
# 7  40  400  4000

# %%
# range(start, stop, step):
# This function generates a sequence of numbers starting from start, up to but not including stop, incrementing by step.

# %% [markdown]
# # Q3. You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The function should print the sum to the console. For example, if the 'Values' column of df contains the values [10, 20, 30, 40, 50], your function should calculate and print the sum of the first three values, which is 60.

# %%
import pandas as pd

df = pd.DataFrame(data = {'Values':[10,20,30,40,50]})

# %%
df
# Out:
#    Values
# 0      10
# 1      20
# 2      30
# 3      40
# 4      50

# %%
def sum_of_value(df):
    sum = 0
    for val in df['Values'][0:3]:
        sum = sum+val
    print("The sum of First 3 Values is:",sum)

# %%
sum_of_value(df)
# Out:
# The sum of First 3 Values is: 60

# %% [markdown]
# # Q4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column 'Word_Count' that contains the number of words in each row of the 'Text' column.

# %%
df = pd.DataFrame(data = {'Text':['Vidit Singh','Anuj','Yash']})

# %%
def add_word_count_column(df):
    # Function to count the number of words in a text string
    def word_count(text):
        return len(text.split())
    
    # Apply the word_count function to the 'Text' column and create the 'Word_Count' column
    df['Word_Count'] = df['Text'].apply(word_count)
    
    return df

# %%
print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#           Text
# 0  Vidit Singh
# 1         Anuj
# 2         Yash

# %%
# Adding the 'Word_Count' column
df_with_word_count = add_word_count_column(df)
print("\nDataFrame with Word_Count column:")
print(df_with_word_count)
# Out:
# DataFrame with Word_Count column:
#           Text  Word_Count
# 0  Vidit Singh           2
# 1         Anuj           1
# 2         Yash           1

# %% [markdown]
# # Q5. How are DataFrame.size() and DataFrame.shape() different?

# %% [markdown]
# - The DataFrame.size and DataFrame.shape are attributes in pandas that provide different information about the DataFrame.
#
# DataFrame.size:
#
# - Description: Returns the number of elements in the DataFrame.
# - Type of Output: Single integer.
# - Calculation: This is equivalent to the product of the number of rows and columns (i.e., rows * columns).
# - Example Usage: df.size
#
# DataFrame.shape:
#
# - Description: Returns a tuple representing the dimensionality of the DataFrame.
# - Type of Output: Tuple of two integers.
#
# Components:
# - The first integer is the number of rows.
# - The second integer is the number of columns.
# - Example Usage: df.shape

# %%
data = {'A':[10,20,30,40],'B':[1,2,3,4]}
df = pd.DataFrame(data)
df
# Out:
#     A  B
# 0  10  1
# 1  20  2
# 2  30  3
# 3  40  4

# %%
# df.size:
print('The size of the dataframe is: ',df.size)

#df.shape:
print('The shape of dataframe is: ',df.shape)
# Out:
# The size of the dataframe is:  8
# The shape of dataframe is:  (4, 2)

# %% [markdown]
# # Q6. Which function of pandas do we use to read an excel file?

# %% [markdown]
# - In pandas, the function used to read an Excel file is pd.read_excel().

# %%
# Here is a basic example of how to use pd.read_excel():
df = pd.read_excel('LUSID Excel - Setting up your market data.xlsx')
df
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN         NaN         NaN
# 7          NaN         NaN         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# 14         NaN         NaN         NaN
# 15         NaN         NaN         NaN
# 16         NaN         NaN         NaN
# 17         NaN         NaN         NaN
# 18         NaN         NaN         NaN
# 19         NaN         NaN         NaN
# 20         NaN         NaN         NaN
# 21         NaN         NaN         NaN
# 22         NaN         NaN         NaN
# ...

# %% [markdown]
# # Q7. You have a Pandas DataFrame df that contains a column named 'Email' that contains email addresses in the format 'username@domain.com'. Write a Python function that creates a new column 'Username' in df that contains only the username part of each email address.

# %%
import pandas as pd

def Username(df):
    df['Username'] = df['Email'].apply(lambda x: x.split('@')[0])
    return df

data = {'Email':['user1@example.com', 'user2@test.com', 'user3@domain.com']}

df = pd.DataFrame(data)

# Extract usernames and add to the DataFrame
df = Username(df)
print(df)
# Out:
#                Email Username
# 0  user1@example.com    user1
# 1     user2@test.com    user2
# 2   user3@domain.com    user3

# %% [markdown]
# # Q8. You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The function should return a new DataFrame that contains only the selected rows.

# %%
import pandas as pd
def select_row(df):
    filtered_df = df[(df['A']>5) & (df['B']<10)]
    return filtered_df

data = {'A':[3,8,6,2,9,8,9],'B':[5,2,9,3,1,2,1],'C':[1,7,4,5,2,7,2]}
df = pd.DataFrame(data)

selected_df = select_row(df)
print(selected_df)
# Out:
#    A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  9  1  2
# 5  8  2  7
# 6  9  1  2

# %% [markdown]
# # Q9. Given a Pandas DataFrame df with a column 'Values', write a Python function to calculate the mean, median, and standard deviation of the values in the 'Values' column.

# %%
def descriptive_stats(df):
    mean = df['Values'].mean()
    median = df['Values'].median()
    std_dev = df['Values'].std()
    return mean,median,std_dev

df = pd.DataFrame({'Values': [1,2,3,4,5]})

df_descriptive_stats = descriptive_stats(df)
print(df_descriptive_stats)
# Out:
# (3.0, 3.0, 1.5811388300841898)

# %% [markdown]
# # Q10. Given a Pandas DataFrame df with a column 'Sales' and a column 'Date', write a Python function to create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days for each row in the DataFrame. The moving average should be calculated using a window of size 7 and should include the current day.

# %%
import pandas as pd
def calculate_moving_average(df):
    # Ensure the dataframe is sorted by date
    df = df.sort_values(by='Date')
    
    # Calculate the 7-day moving average of Sales
    df['MovingAverage'] = df['Sales'].rolling(window=7,min_periods=1).mean()
    
    return df

# %%
data = {
    'Date':pd.date_range(start='2023-01-01',periods=5,freq='D'),
    'Sales':[100,200,150,300,250]
}
df = pd.DataFrame(data)

# Calculating the moving average
df = calculate_moving_average(df)
print(df)
# Out:
#         Date  Sales  MovingAverage
# 0 2023-01-01    100          100.0
# 1 2023-01-02    200          150.0
# 2 2023-01-03    150          150.0
# 3 2023-01-04    300          187.5
# 4 2023-01-05    250          200.0

# %% [markdown]
# - DataFrame: A table with rows and columns. In this case, it has 'Sales' (number of sales) and 'Date' (dates corresponding to sales).
# - Moving Average: A calculation to analyze data points by creating a series of averages of different subsets of the full data set. A 7-day moving average takes the average of the current day and the previous 6 days.
# - The rolling method in pandas is used to perform rolling window calculations. It creates a window of specified size that slides over the data, allowing you to apply various calculations (e.g., mean, sum) to each window.

# %% [markdown]
# # Q11. You have a Pandas DataFrame df with a column 'Date'. Write a Python function that creates a new column 'Weekday' in the DataFrame. The 'Weekday' column should contain the weekday name (e.g. Monday, Tuesday) corresponding to each date in the 'Date' column.

# %%
import pandas as pd

def add_weekday_column(df):
    # Ensure the 'Date' column is in datetime format
    df['Date'] = pd.to_datetime(df['Date'])
    
    # Create the 'Weekday' column
    df['Weekday'] = df['Date'].dt.day_name()
    
    return df

# Example usage
data = {
    'Date': pd.date_range(start='2023-01-01', periods=5, freq='D')
}
df = pd.DataFrame(data)

# Add the 'Weekday' column
df = add_weekday_column(df)
print(df)
# Out:
#         Date    Weekday
# 0 2023-01-01     Sunday
# 1 2023-01-02     Monday
# 2 2023-01-03    Tuesday
# 3 2023-01-04  Wednesday
# 4 2023-01-05   Thursday

# %% [markdown]
# # Q12. Given a Pandas DataFrame df with a column 'Date' that contains timestamps, write a Pythonfunction to select all rows where the date is between '2023-01-01' and '2023-01-31'.

# %%
import pandas as pd

def filter_date_range(df):
    # Ensure the 'Date' column is in datetime format
    df['Date'] = pd.to_datetime(df['Date'])
    
    # Define the start and end date for the filter
    start_date = '2023-01-01'
    end_date = '2023-01-31'
    
    # Filter the DataFrame for rows within the date range
    filtered_df = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]
    
    return filtered_df

# Example usage
data = {
    'Date': pd.date_range(start='2022-12-25', periods=50, freq='D'),
    'Value': range(50)
}
df = pd.DataFrame(data)

# Filter the DataFrame for the specified date range
filtered_df = filter_date_range(df)
print(filtered_df)
# Out:
#          Date  Value
# 7  2023-01-01      7
# 8  2023-01-02      8
# 9  2023-01-03      9
# 10 2023-01-04     10
# 11 2023-01-05     11
# 12 2023-01-06     12
# 13 2023-01-07     13
# 14 2023-01-08     14
# 15 2023-01-09     15
# 16 2023-01-10     16
# 17 2023-01-11     17
# 18 2023-01-12     18
# 19 2023-01-13     19
# 20 2023-01-14     20
# 21 2023-01-15     21
# 22 2023-01-16     22
# 23 2023-01-17     23
# 24 2023-01-18     24
# 25 2023-01-19     25
# 26 2023-01-20     26
# 27 2023-01-21     27
# 28 2023-01-22     28
# 29 2023-01-23     29
# 30 2023-01-24     30
# 31 2023-01-25     31
# 32 2023-01-26     32
# 33 2023-01-27     33
# 34 2023-01-28     34
# 35 2023-01-29     35
# 36 2023-01-30     36
# 37 2023-01-31     37

# %% [markdown]
# # Q13. To use the basic functions of pandas, what is the first and foremost necessary library that needs to be imported?

# %% [markdown]
# - To use the basic functions of pandas, the first and foremost necessary library that needs to be imported is pandas.
# - import pandas as pd: This statement imports the pandas library and gives it the alias pd. Using pd as an alias is a common convention and makes it easier to reference pandas functions and classes throughout your code.
